# %% [markdown]
# ### 学习开源库folium制图基础
# 1.底图设定
# 2.添加标记Maker

# %%
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# #### 底图显示，folium底图包括：'OpenStreetMap'（默认，有时打不开），'Stamen Terrain'，'Stamen Watercolor'等。
# 云大坐标：（102.84，24.83）

# %%
map = folium.Map(location=[24.83, 102.84],tiles='Stamen Terrain')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### 设置高德、百度、天地图等为底图
# 高德地图(中英文版): 'https://webrd02.is.autonavi.com/appmaptile?lang=zh_en&size=1&scale=1&style=8&x={x}&y={y}&z={z}'.
# 高德卫星地图：'https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}'
# GeoQ智图中国行政边界图：'http://thematic.geoq.cn/arcgis/rest/services/ThematicMaps/administrative_division_boundaryandlabel/MapServer/tile/{z}/{y}/{x}',
# GeoQ智图水系图：'http://thematic.geoq.cn/arcgis/rest/services/ThematicMaps/WorldHydroMap/MapServer/tile/{z}/{y}/{x}'

# %%
folium.Map(location=[24.83, 102.84], 
           tiles='https://webrd02.is.autonavi.com/appmaptile?lang=zh_en&size=1&scale=1&style=8&x={x}&y={y}&z={z}',
           attr='高德地图-中英文版')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 folium.Map(location=[24.83, 102.84],
#       2            tiles='https://webrd02.is.autonavi.com/appmaptile?lang=zh_en&size=1&scale=1&style=8&x={x}&y={y}&z={z}',
#       3            attr='高德地图-中英文版')
#
# NameError: name 'folium' is not defined

# %%
folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 添加位置标记Marker
# 云南大学位置：（24.827, 102.850）
# 云南师范大学位置：（24.861, 102.854）
# 春城公园：（24.877, 102.830）
# 洛龙公园：（24.889, 102.819）

# %%
# map = folium.Map(location=[24.827, 102.850], 
#            tiles='https://webrd02.is.autonavi.com/appmaptile?lang=zh_en&size=1&scale=1&style=8&x={x}&y={y}&z={z}',
#            attr='高德地图-中英文版')
map = folium.Map(location=[24.83, 102.84], 
           tiles='	https://tile.openstreetmap.org/{z}/{x}/{y}.png',
           attr='高德卫星地图',
           zoom_start=12
           )

folium.Marker(location=[24.827, 102.850], tooltip='大学', popup='Yunnan University').add_to(map)
folium.Marker(location=[24.861, 102.854], tooltip='大学', popup='Yunnan Normal University').add_to(map)
folium.Marker(location=[24.877, 102.830], tooltip='公园', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.889, 102.819], tooltip='公园', popup='Luolong Park', icon=folium.Icon(color='green')).add_to(map)



folium.Marker(location=[24.827123, 102.847363], tooltip='图书馆', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.829104,102.844347], tooltip='文典广场   ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.831864,102.847684], tooltip='明远楼     ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.830730,102.857348], tooltip='校医院     ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.831467,102.858132], tooltip='体育馆     ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.836014,102.846267], tooltip='云南大学北 ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.834093,102.843014], tooltip='泽湖       ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.823276,102.847465], tooltip='田径场     ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.825765,102.851500], tooltip='南苑食堂   ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.831691,102.842390], tooltip='志愿食堂   ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
folium.Marker(location=[24.827553,102.850379], tooltip='格物楼     ', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
 
#你不会那种小声的说话吗，
#就是那种不发鼻音那种

""" 24.829104°N 102.844347°E 文典广场   
24.831864°N 102.847684°E 明远楼     
24.830730°N 102.857348°E 校医院     
24.831467°N 102.858132°E 体育馆     
24.836014°N 102.846267°E 云南大学北门
24.834093°N 102.843014°E 泽湖       
24.823276°N 102.847465°E 田径场     
24.825765°N 102.851500°E 南苑食堂       
24.831691°N 102.842390°E 志愿食堂       
24.827553°N 102.850379°E 格物楼     """ 




map
#folium.Marker(location=[24.81, 102.83], tooltip='test', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
#folium.Marker(location=[24.81, 102.83], tooltip='test', popup='Chuncheng Park', icon=folium.Icon(color='green')).add_to(map)
#24°49'37"N 102°50'50"E24.827123°N 102.847363°E
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
### 对标记添加图片
path_picture = 'data/Section_6/云南大学.jpeg'
map = folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图',
           zoom_start=12
           )
# icon_picture = folium.features.CustomIcon(icon_image=path_picture, icon_size=(30,30))
# folium.Marker(location=[24.827, 102.850], tooltip='大学', popup='Yunnan University', icon=icon_picture).add_to(map)
import base64
import cv2
height, width = cv2.imread(path_picture).shape[:2]
encoded = base64.b64encode(open(path_picture, 'rb').read()) ##  图像编码
html = '<img src="data:image; base64,{}">'.format(encoded.decode('UTF-8'))  ### 定义图片的html格式
# html = '''<h>云南大学</h>
#           <br><img src="data:image;base64,{}"><br>
#           <p>这是云南大学的标志性建筑...</p>'''.format(encoded.decode('UTF-8'))     ### 定义文字+图片的html格式
iframe = folium.IFrame(html=html, width=width, height=height)
popup_picture = folium.Popup(iframe, max_width=500)
height, width = cv2.imread(path_picture).shape[:2]
folium.Marker(location=[24.827, 102.850], popup=popup_picture, tooltip='云南大学').add_to(map)
map
# Out:
# [ WARN:0@0.070] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('data/Section_6/云南大学.jpeg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 12
#      10 import base64
#      11 import cv2
# ---> 12 height, width = cv2.imread(path_picture).shape[:2]
#      13 encoded = base64.b64encode(open(path_picture, 'rb').read()) ##  图像编码
#      14 html = '<img src="data:image; base64,{}">'.format(encoded.decode('UTF-8'))  ### 定义图片的html格式
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# #### 添加多段线Polylines

# %%
map = folium.Map(location=[24.83, 102.84], 
           tiles='https://webst02.is.autonavi.com/appmaptile?style=6&x={x}&y={y}&z={z}',
           attr='高德卫星地图')

trail_coordinates = [
    (24.827, 102.850),
    (24.889, 102.819),
]

folium.PolyLine(trail_coordinates, tooltip="yunnan univeristy->chuncheng park", color='red').add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 将在线地图保存为html文件

# %%
map.save("data/Section_6/index.html")

# %% [markdown]
# #### 课后练习
# 利用folium开源库制作标记云南大学和选课同学家乡位置的地图，并绘制云南大学与选课同学家乡的直线路径。
